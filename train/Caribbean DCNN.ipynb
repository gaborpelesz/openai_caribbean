# %% [markdown]
# ## augmented_data_v2

# %%
import zipfile
# !rm -r ./augmented_data
# !rm ./augm_data_v2.zip
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1x8LBri6mji7OEfylBtsapZxHixS-Dv_J' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1x8LBri6mji7OEfylBtsapZxHixS-Dv_J" -O augm_data_v2.zip && rm -rf /tmp/cookies.txt

with zipfile.ZipFile('./augm_data_v2.zip', 'r') as zip_ref:
        print('The extraction of the images can take some time...')
        zip_ref.extractall('./')
        print('Extraction done')
# Out:
# rm: cannot remove './augmented_data': No such file or directory
# rm: cannot remove './augm_data_v2.zip': No such file or directory
# --2019-12-11 11:59:10--  https://docs.google.com/uc?export=download&confirm=CClR&id=1x8LBri6mji7OEfylBtsapZxHixS-Dv_J
# Resolving docs.google.com (docs.google.com)... 216.58.214.238, 2a00:1450:400d:802::200e
# Connecting to docs.google.com (docs.google.com)|216.58.214.238|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f7u6llfu5bs4i425fhhki6e4iae00453/1576058400000/17506844314399870089/*/1x8LBri6mji7OEfylBtsapZxHixS-Dv_J?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-12-11 11:59:10--  https://doc-08-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f7u6llfu5bs4i425fhhki6e4iae00453/1576058400000/17506844314399870089/*/1x8LBri6mji7OEfylBtsapZxHixS-Dv_J?e=download
# Resolving doc-08-24-docs.googleusercontent.com (doc-08-24-docs.googleusercontent.com)... 172.217.19.97, 2a00:1450:400d:804::2001
# Connecting to doc-08-24-docs.googleusercontent.com (doc-08-24-docs.googleusercontent.com)|172.217.19.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘augm_data_v2.zip’
#
# augm_data_v2.zip        [              <=>   ] 899,26M  17,3MB/s    in 58s
#
# 2019-12-11 12:00:09 (15,4 MB/s) - ‘augm_data_v2.zip’ saved [942947501]

# %% [markdown]
# ## augmented_data_v3
# - with half-half train-validation
# - si_augmented train and cut_half validation for healthy and irregular

# %%
import zipfile
# !rm -r ./augmented_data
# !rm ./augm_data_v3.zip
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1wzceLpAZW_5Lw5KW3W3HKgAPPvz1cuSG' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1wzceLpAZW_5Lw5KW3W3HKgAPPvz1cuSG" -O augm_data_v3.zip && rm -rf /tmp/cookies.txt

with zipfile.ZipFile('./augm_data_v3.zip', 'r') as zip_ref:
        print('The extraction of the images can take some time...')
        zip_ref.extractall('./')
        print('Extraction done')
# Out:
# --2019-12-09 14:30:26--  https://docs.google.com/uc?export=download&confirm=c9jE&id=1wzceLpAZW_5Lw5KW3W3HKgAPPvz1cuSG
# Resolving docs.google.com (docs.google.com)... 74.125.20.139, 74.125.20.102, 74.125.20.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.20.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bb58h82obu8d4eelsl6civemqm5qflhi/1575900000000/17506844314399870089/*/1wzceLpAZW_5Lw5KW3W3HKgAPPvz1cuSG?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2019-12-09 14:30:26--  https://doc-14-24-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/bb58h82obu8d4eelsl6civemqm5qflhi/1575900000000/17506844314399870089/*/1wzceLpAZW_5Lw5KW3W3HKgAPPvz1cuSG?e=download
# Resolving doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)... 74.125.195.132, 2607:f8b0:400e:c09::84
# Connecting to doc-14-24-docs.googleusercontent.com (doc-14-24-docs.googleusercontent.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘augm_data_v3.zip’
#
# augm_data_v3.zip        [     <=>            ] 694.60M   127MB/s    in 5.8s
#
# 2019-12-09 14:30:33 (119 MB/s) - ‘augm_data_v3.zip’ saved [728339119]
#
# The extraction of the images can take some time...
# Extraction done

# %% [markdown]
# # SWISH

# %%
from keras.backend import sigmoid

def swish(x, beta = 1):
    return (x * sigmoid(beta * x))

from keras.utils.generic_utils import get_custom_objects
from keras.layers import Activation

swish = Activation(swish)
swish.__name__ = 'swish'

get_custom_objects().update({'swish': swish})
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # RUN FROM HERE

# %%
SEED = 777

train_path = './augmented_data/train/'
val_path = './augmented_data/validation/'

epochs = 30
#with 3 was it the best
batch_size = 3
image_size = (280, 280)
image_shape = (*image_size, 3) # add RGB channel

# %%
import tensorflow as tf
import numpy as np
from keras import optimizers
from keras.utils import plot_model

tf.random.set_seed(SEED)
np.random.seed(SEED)

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

model = Sequential()
model.add(Conv2D(128, (3, 3), input_shape=image_shape))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(128, (3, 3)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.4))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.1))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('swish'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# the model so far outputs 3D feature maps (height, width, features)
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(256))
model.add(Activation('swish'))
model.add(Dense(64, activation='swish'))
model.add(Dense(5))
model.add(Activation('softmax'))
# COMPILE
own_rms_prop = optimizers.RMSprop(learning_rate=0.0005, rho=0.9)
model.compile(loss='categorical_crossentropy',
              optimizer=own_rms_prop,
              metrics=['accuracy'])
model.summary()
plot_model(model, to_file='own_dcnn.png', show_shapes=True, show_layer_names=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 278, 278, 128)     3584
# _________________________________________________________________
# activation_9 (Activation)    (None, 278, 278, 128)     0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 92, 92, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 90, 90, 128)       147584
# _________________________________________________________________
# activation_10 (Activation)   (None, 90, 90, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 45, 45, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 43, 43, 64)        73792
# _________________________________________________________________
# activation_11 (Activation)   (None, 43, 43, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 21, 21, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 21, 21, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 19, 19, 64)        36928
# _________________________________________________________________
# activation_12 (Activation)   (None, 19, 19, 64)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 64)          36928
# _________________________________________________________________
# activation_13 (Activation)   (None, 7, 7, 64)          0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               147712
# _________________________________________________________________
# activation_14 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_15 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 463,301
# Trainable params: 463,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_path,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        val_path,
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical')

num_of_train_samples = len(train_generator)*batch_size
num_of_val_samples = len(validation_generator)*batch_size
# Out:
# Found 14675 images belonging to 5 classes.
# Found 2695 images belonging to 5 classes.

# %%
import os
from keras.callbacks import EarlyStopping, ModelCheckpoint 

MODEL_NAME = 'augmented_test3.h5'
history = None

if not os.path.exists(MODEL_NAME):
    # es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=100)
    mc = ModelCheckpoint(MODEL_NAME, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

    history = model.fit_generator(
            train_generator,
            steps_per_epoch=num_of_train_samples // batch_size,
            epochs=epochs,
            validation_data=validation_generator,
            validation_steps=num_of_val_samples // batch_size,
            callbacks=[mc])
            #callbacks=[es, mc])
else:
    print('Change model name because calling this will delete the existing "{}" file'.format(MODEL_NAME))
# Out:
# Epoch 1/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 1.2168 - accuracy: 0.4993 - val_loss: 0.0049 - val_accuracy: 0.6019
#
# Epoch 00001: val_loss improved from inf to 0.00486, saving model to augmented_test3.h5
# Epoch 2/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.9413 - accuracy: 0.6297 - val_loss: 0.6901 - val_accuracy: 0.6683
#
# Epoch 00002: val_loss did not improve from 0.00486
# Epoch 3/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 0.8746 - accuracy: 0.6661 - val_loss: 1.8492 - val_accuracy: 0.5707
#
# Epoch 00003: val_loss did not improve from 0.00486
# Epoch 4/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 0.8312 - accuracy: 0.6866 - val_loss: 2.4594 - val_accuracy: 0.6790
#
# Epoch 00004: val_loss did not improve from 0.00486
# Epoch 5/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.8076 - accuracy: 0.7001 - val_loss: 1.2383 - val_accuracy: 0.7187
#
# Epoch 00005: val_loss did not improve from 0.00486
# Epoch 6/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.7878 - accuracy: 0.7097 - val_loss: 1.2553 - val_accuracy: 0.6186
#
# Epoch 00006: val_loss did not improve from 0.00486
# Epoch 7/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 0.7801 - accuracy: 0.7157 - val_loss: 0.0128 - val_accuracy: 0.6998
#
# Epoch 00007: val_loss did not improve from 0.00486
# Epoch 8/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.7713 - accuracy: 0.7278 - val_loss: 0.3753 - val_accuracy: 0.5306
#
# Epoch 00008: val_loss did not improve from 0.00486
# Epoch 9/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.7770 - accuracy: 0.7280 - val_loss: 1.3398 - val_accuracy: 0.6846
#
# Epoch 00009: val_loss did not improve from 0.00486
# Epoch 10/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.7701 - accuracy: 0.7314 - val_loss: 2.6376 - val_accuracy: 0.6249
#
# Epoch 00010: val_loss did not improve from 0.00486
# Epoch 11/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.7772 - accuracy: 0.7322 - val_loss: 1.8961 - val_accuracy: 0.6905
#
# Epoch 00011: val_loss did not improve from 0.00486
# Epoch 12/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.7869 - accuracy: 0.7280 - val_loss: 0.7714 - val_accuracy: 0.5113
#
# Epoch 00012: val_loss did not improve from 0.00486
# Epoch 13/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.8107 - accuracy: 0.7274 - val_loss: 3.3623e-04 - val_accuracy: 0.7306
#
# Epoch 00013: val_loss improved from 0.00486 to 0.00034, saving model to augmented_test3.h5
# Epoch 14/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.7975 - accuracy: 0.7304 - val_loss: 1.0790 - val_accuracy: 0.6223
#
# Epoch 00014: val_loss did not improve from 0.00034
# Epoch 15/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.8603 - accuracy: 0.7171 - val_loss: 4.7871 - val_accuracy: 0.6917
#
# Epoch 00015: val_loss did not improve from 0.00034
# Epoch 16/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.8415 - accuracy: 0.7194 - val_loss: 0.2047 - val_accuracy: 0.7176
#
# Epoch 00016: val_loss did not improve from 0.00034
# Epoch 17/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.8795 - accuracy: 0.7161 - val_loss: 0.2994 - val_accuracy: 0.7217
#
# Epoch 00017: val_loss did not improve from 0.00034
# Epoch 18/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 0.9208 - accuracy: 0.7069 - val_loss: 0.0087 - val_accuracy: 0.6831
#
# Epoch 00018: val_loss did not improve from 0.00034
# Epoch 19/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 0.9149 - accuracy: 0.7042 - val_loss: 1.8748 - val_accuracy: 0.6134
#
# Epoch 00019: val_loss did not improve from 0.00034
# Epoch 20/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 0.9808 - accuracy: 0.6882 - val_loss: 0.2579 - val_accuracy: 0.7013
#
# Epoch 00020: val_loss did not improve from 0.00034
# Epoch 21/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.0091 - accuracy: 0.6822 - val_loss: 1.0198 - val_accuracy: 0.5399
#
# Epoch 00021: val_loss did not improve from 0.00034
# Epoch 22/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 0.9773 - accuracy: 0.6722 - val_loss: 1.7884 - val_accuracy: 0.7161
#
# Epoch 00022: val_loss did not improve from 0.00034
# Epoch 23/30
# 4892/4892 [==============================] - 294s 60ms/step - loss: 1.0212 - accuracy: 0.6600 - val_loss: 1.5639 - val_accuracy: 0.5173
#
# Epoch 00023: val_loss did not improve from 0.00034
# Epoch 24/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.0522 - accuracy: 0.6452 - val_loss: 0.0327 - val_accuracy: 0.6130
#
# Epoch 00024: val_loss did not improve from 0.00034
# Epoch 25/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.0652 - accuracy: 0.6465 - val_loss: 0.2472 - val_accuracy: 0.6071
#
# Epoch 00025: val_loss did not improve from 0.00034
# Epoch 26/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.1133 - accuracy: 0.6300 - val_loss: 0.2094 - val_accuracy: 0.6460
#
# Epoch 00026: val_loss did not improve from 0.00034
# Epoch 27/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.1671 - accuracy: 0.6171 - val_loss: 0.0312 - val_accuracy: 0.6464
#
# Epoch 00027: val_loss did not improve from 0.00034
# Epoch 28/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.1649 - accuracy: 0.6036 - val_loss: 0.6293 - val_accuracy: 0.6178
#
# Epoch 00028: val_loss did not improve from 0.00034
# Epoch 29/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.2040 - accuracy: 0.5891 - val_loss: 0.6482 - val_accuracy: 0.5462
#
# Epoch 00029: val_loss did not improve from 0.00034
# Epoch 30/30
# 4892/4892 [==============================] - 293s 60ms/step - loss: 1.1810 - accuracy: 0.5819 - val_loss: 0.0090 - val_accuracy: 0.6163
#
# Epoch 00030: val_loss did not improve from 0.00034

# %%
import matplotlib.pyplot as plt

def plot_losses(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper left')
    plt.show()
    
def plot_acc(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train accuracy', 'Validation accuracy'], loc='lower right')
    plt.show()

# %%
plot_losses(history)

# %%
plot_acc(history)
